# %%
x=c(0.25,0.50,0.75,1,1.25,1.5,1.75,2,2.25,2.5)
x_square = x^2
y=c(1.42,1.39,1.55,1.89,2.43,3.15,4.05,5.15,6.43,7.89)
 y.lm<-lm(y~x+x_square)
summary(y.lm)
# Out:
# Call:
# lm(formula = y ~ x + x_square)
#
# Residuals:
#       Min        1Q    Median        3Q       Max
# -0.005364 -0.002727  0.001045  0.002409  0.003273
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)  1.633000   0.004196   389.2  < 2e-16 ***
# x           -1.232182   0.007010  -175.8 5.09e-14 ***
# x_square     1.494545   0.002484   601.6  < 2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 0.003568 on 7 degrees of freedom
# Multiple R-squared:      1,	Adjusted R-squared:      1
# F-statistic: 1.859e+06 on 2 and 7 DF,  p-value: < 2.2e-16

# %%
layout(matrix(c(1,2,3,4),2,2))
plot(y.lm)
# Out:
# Plot with title “”

# %%
anova(y.lm)
# Out:
#           Df Sum Sq       Mean Sq      F value   Pr(>F)
# x         1  4.270322e+01 4.270322e+01 3355253.4 3.817102e-21
# x_square  1  4.606936e+00 4.606936e+00  361973.6 9.255077e-18
# Residuals 7  8.909091e-05 1.272727e-05        NA           NA

# %%
names(summary(y.lm))
# Out:
#  [1] "call"          "terms"         "residuals"     "coefficients"
#  [5] "aliased"       "sigma"         "df"            "r.squared"
#  [9] "adj.r.squared" "fstatistic"    "cov.unscaled"

# %%
# To calculate the hypothesis that β2=0 we have to calculate the SSr for the reduced model with only β1,β0
y.reduced<-lm(y~x)
summary.aov(y.reduced)
# Out:
#             Df Sum Sq Mean Sq F value   Pr(>F)
# x            1  42.70   42.70   74.15 2.56e-05 ***
# Residuals    8   4.61    0.58
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1

# %%
# so for the F statistic we do the following
F0<-(4.61 - 8.909091e-05)/1.272727e-05

# %%
#PLOTS OF RESIDUALS WITH RESPECT TO x AND fit(y.lm).
y.res <- resid(y.lm)
plot(x,y.res)
y.fitted<-fitted(y.lm)
plot(y.fitted,y.res)
# Out:
# plot without title
# plot without title

# %%
summary(y.lm)$coefficients[,1]
# Out:
# (Intercept)           x    x_square
#    1.633000   -1.232182    1.494545
